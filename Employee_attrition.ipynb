# %% [markdown]
# **ROBIN COMPANIES EMPLOYEES DATA**

# %% [markdown]
# The dataset contains employees information from Robins company.

# %% [markdown]
# Purpose is to analyse,drive insights and predict the likelihood of the employee leaving the company.

# %%
# Importation of various libraries.
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df=pd.read_csv('employee_attrition_data.csv')
df.head(5)
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# The Company has ever employed 1000 people.

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 0    505
# 1    495
# Name: count, dtype: int64

# %% [markdown]
# 495 employees has ever left the company.

# %% [markdown]
# 505 are still on job.And so,the max employees in the company are 505.

# %%
df['Department'].value_counts()
# Out:
# Department
# Sales          209
# Finance        206
# Engineering    204
# HR             191
# Marketing      190
# Name: count, dtype: int64

# %% [markdown]
# Many people are emplloyed in sales department.

# %%
df['Job_Title'].value_counts()
# Out:
# Job_Title
# Engineer         214
# Manager          206
# Accountant       206
# Analyst          195
# HR Specialist    179
# Name: count, dtype: int64

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 999          999   59    Male        Sales  HR Specialist                 1
# 523          523   59    Male        Sales  HR Specialist                 7
# 626          626   59    Male      Finance       Engineer                 7
# 502          502   59    Male  Engineering  HR Specialist                 8
# 28            28   59  Female    Marketing     Accountant                 8
# ..           ...  ...     ...          ...            ...               ...
# 741          741   25  Female        Sales  HR Specialist                10
# 470          470   25    Male        Sales     Accountant                 3
# 592          592   25  Female        Sales     Accountant                 8
# 685          685   25  Female      Finance  HR Specialist                 5
# 783          783   25    Male    Marketing        Analyst                10
#
# ...

# %% [markdown]
# The oldest employee is 59 years old.

# %%
df['Years_at_Company'].max()
# Out:
# 10

# %% [markdown]
# The employee whos stayed in the company the longest is 10yrs.

# %%
df.sort_values(by='Age',ascending=True)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 426          426   25  Female  Engineering     Accountant                 4
# 480          480   25    Male      Finance       Engineer                 7
# 741          741   25  Female        Sales  HR Specialist                10
# 706          706   25    Male    Marketing     Accountant                10
# 470          470   25    Male        Sales     Accountant                 3
# ..           ...  ...     ...          ...            ...               ...
# 502          502   59    Male  Engineering  HR Specialist                 8
# 35            35   59    Male           HR  HR Specialist                 7
# 28            28   59  Female    Marketing     Accountant                 8
# 448          448   59    Male  Engineering     Accountant                 9
# 999          999   59    Male        Sales  HR Specialist                 1
#
# ...

# %%
df.sort_values(by='Satisfaction_Level',ascending=True)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 87            87   26    Male           HR       Engineer                10
# 957          957   35  Female        Sales     Accountant                 7
# 497          497   46    Male    Marketing        Analyst                 3
# 908          908   49  Female      Finance     Accountant                 5
# 955          955   41  Female  Engineering  HR Specialist                 6
# ..           ...  ...     ...          ...            ...               ...
# 994          994   47    Male    Marketing  HR Specialist                 2
# 32            32   30  Female           HR  HR Specialist                 8
# 26            26   55  Female        Sales        Analyst                 6
# 661          661   37    Male    Marketing        Manager                10
# 682          682   52  Female           HR        Manager                 5
#
# ...

# %%
df.sort_values(by='Satisfaction_Level',ascending=False)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 682          682   52  Female           HR        Manager                 5
# 661          661   37    Male    Marketing        Manager                10
# 26            26   55  Female        Sales        Analyst                 6
# 32            32   30  Female           HR  HR Specialist                 8
# 994          994   47    Male    Marketing  HR Specialist                 2
# ..           ...  ...     ...          ...            ...               ...
# 955          955   41  Female  Engineering  HR Specialist                 6
# 908          908   49  Female      Finance     Accountant                 5
# 497          497   46    Male    Marketing        Analyst                 3
# 957          957   35  Female        Sales     Accountant                 7
# 87            87   26    Male           HR       Engineer                10
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
df1=df['Department']=='Marketing'
df.loc[df1]
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 0              0   27    Male  Marketing        Manager                 9
# 2              2   59  Female  Marketing        Analyst                 8
# 6              6   58    Male  Marketing  HR Specialist                 5
# 9              9   57  Female  Marketing       Engineer                 7
# 11            11   50    Male  Marketing     Accountant                 3
# ..           ...  ...     ...        ...            ...               ...
# 982          982   47  Female  Marketing       Engineer                 1
# 984          984   59    Male  Marketing        Analyst                 5
# 989          989   51  Female  Marketing       Engineer                 8
# 991          991   47    Male  Marketing        Manager                 2
# 994          994   47    Male  Marketing  HR Specialist                 2
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
sns.boxplot(df['Satisfaction_Level'])
# Out:
# <Axes: >

# %% [markdown]
# There is no outliers in the satisfaction_level.

# %%
df.describe()
# Out:
#        Employee_ID          Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000  1000.000000       1000.000000         1000.000000
# mean    499.500000    42.205000          5.605000            0.505995
# std     288.819436    10.016452          2.822223            0.289797
# min       0.000000    25.000000          1.000000            0.001376
# 25%     249.750000    33.000000          3.000000            0.258866
# 50%     499.500000    43.000000          6.000000            0.505675
# 75%     749.250000    51.000000          8.000000            0.761135
# max     999.000000    59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# ...

# %%
df.sort_values(by='Salary',ascending=False)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 519          519   58    Male  Engineering  HR Specialist                 1
# 213          213   55  Female      Finance     Accountant                 6
# 237          237   44  Female           HR       Engineer                 4
# 78            78   35    Male      Finance        Manager                 4
# 683          683   26  Female  Engineering  HR Specialist                 6
# ..           ...  ...     ...          ...            ...               ...
# 59            59   28  Female        Sales        Analyst                10
# 922          922   39    Male    Marketing     Accountant                 7
# 802          802   57    Male    Marketing  HR Specialist                 6
# 996          996   50    Male  Engineering        Manager                 1
# 834          834   26    Male      Finance        Manager                 3
#
# ...

# %% [markdown]
# A HR specialist in the enginnering department earns the most.

# %%
df2=df['Department']=='HR'
hr_department=df.loc[df2]
hr_department
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 10            10   57  Female         HR  HR Specialist                 5
# 12            12   44    Male         HR       Engineer                 1
# 19            19   45  Female         HR        Manager                 5
# 32            32   30  Female         HR  HR Specialist                 8
# 34            34   36  Female         HR     Accountant                 6
# ..           ...  ...     ...        ...            ...               ...
# 981          981   55  Female         HR  HR Specialist                 9
# 992          992   46  Female         HR        Analyst                 8
# 993          993   47  Female         HR        Analyst                 5
# 995          995   39  Female         HR  HR Specialist                 3
# 998          998   37  Female         HR  HR Specialist                 2
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
hr_department['Attrition'].value_counts()
# Out:
# Attrition
# 1    96
# 0    95
# Name: count, dtype: int64

# %% [markdown]
# 96 employees have left the HR department ever since the company begun.95 are still in the departent.

# %% [markdown]
# **Focusing on the current employees in the company by department**

# %%
employees_in_hr=(df['Department']=='HR') & (df['Attrition']==0)
hr_department=df.loc[employees_in_hr]
hr_department
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 32            32   30  Female         HR  HR Specialist                 8
# 35            35   59    Male         HR  HR Specialist                 7
# 37            37   47    Male         HR     Accountant                 5
# 40            40   40  Female         HR        Analyst                10
# 48            48   36  Female         HR     Accountant                 8
# ..           ...  ...     ...        ...            ...               ...
# 948          948   59    Male         HR        Analyst                 5
# 950          950   27    Male         HR  HR Specialist                 5
# 959          959   36  Female         HR       Engineer                 8
# 993          993   47  Female         HR        Analyst                 5
# 995          995   39  Female         HR  HR Specialist                 3
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %% [markdown]
# Current HR department employees.

# %%
hr_department.sort_values(by='Years_at_Company',ascending=False)
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 195          195   40  Female         HR       Engineer                10
# 512          512   53    Male         HR     Accountant                10
# 40            40   40  Female         HR        Analyst                10
# 560          560   38  Female         HR       Engineer                10
# 692          692   55    Male         HR       Engineer                10
# ..           ...  ...     ...        ...            ...               ...
# 252          252   32  Female         HR        Analyst                 1
# 840          840   39    Male         HR        Manager                 1
# 148          148   29    Male         HR       Engineer                 1
# 721          721   49    Male         HR  HR Specialist                 1
# 695          695   49  Female         HR        Analyst                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %% [markdown]
# HR enginner has stayed the longest in the company.

# %%
hr_department.sort_values(by='Salary',ascending=False)
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 549          549   28    Male         HR        Manager                 7
# 467          467   42    Male         HR        Manager                 6
# 420          420   45    Male         HR        Manager                 7
# 609          609   25    Male         HR        Analyst                 3
# 940          940   49  Female         HR  HR Specialist                 5
# ..           ...  ...     ...        ...            ...               ...
# 948          948   59    Male         HR        Analyst                 5
# 195          195   40  Female         HR       Engineer                10
# 517          517   32  Female         HR        Manager                 4
# 826          826   27    Male         HR     Accountant                 7
# 541          541   28    Male         HR     Accountant                 2
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %% [markdown]
# Hr manager earns the most and is among the least satisfied.

# %%
hr_department.sort_values(by='Promotion_Last_5Years',ascending=False)
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 32            32   30  Female         HR  HR Specialist                 8
# 276          276   52    Male         HR       Engineer                 6
# 308          308   53    Male         HR        Manager                 4
# 357          357   57  Female         HR        Analyst                 5
# 420          420   45    Male         HR        Manager                 7
# ..           ...  ...     ...        ...            ...               ...
# 665          665   55    Male         HR     Accountant                 9
# 670          670   43    Male         HR        Manager                10
# 304          304   50    Male         HR     Accountant                 3
# 96            96   32    Male         HR     Accountant                 5
# 995          995   39  Female         HR  HR Specialist                 3
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
hr_department['Promotion_Last_5Years'].value_counts()
# Out:
# Promotion_Last_5Years
# 0    50
# 1    45
# Name: count, dtype: int64

# %% [markdown]
# For the current employees in the HR department,45 have been promoted.

# %%
promoted_hr=hr_department['Promotion_Last_5Years']==1
hr_department.loc[promoted_hr]
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 32            32   30  Female         HR  HR Specialist                 8
# 37            37   47    Male         HR     Accountant                 5
# 71            71   48    Male         HR       Engineer                 8
# 79            79   26    Male         HR       Engineer                 6
# 85            85   25    Male         HR        Analyst                 1
# 87            87   26    Male         HR       Engineer                10
# 148          148   29    Male         HR       Engineer                 1
# 179          179   53    Male         HR        Analyst                 3
# 197          197   45  Female         HR       Engineer                 7
# 208          208   47    Male         HR       Engineer                 8
# 233          233   41  Female         HR        Manager                 2
# 250          250   31  Female         HR  HR Specialist                 7
# ...

# %% [markdown]
# The dataset shows employees whos been promoted over the last 5 years in the HR department.

# %%
employees_in_finance=(df['Department']=='Finance')
finance_department=df.loc[employees_in_finance]
finance_department['Attrition'].value_counts()
# Out:
# Attrition
# 1    107
# 0     99
# Name: count, dtype: int64

# %% [markdown]
# In the Finance department,107 employees has ever left the department

# %%
employees_in_finance=(df['Department']=='Finance') & (df['Attrition']==0)
finance_department=df.loc[employees_in_finance]
finance_department
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 17            17   28    Male    Finance     Accountant                 9
# 27            27   52  Female    Finance  HR Specialist                 6
# 39            39   43    Male    Finance     Accountant                 5
# 47            47   39  Female    Finance        Manager                 1
# 50            50   26  Female    Finance  HR Specialist                 5
# ..           ...  ...     ...        ...            ...               ...
# 958          958   55    Male    Finance        Manager                 9
# 962          962   37  Female    Finance        Manager                 3
# 966          966   45  Female    Finance  HR Specialist                 4
# 967          967   59  Female    Finance        Analyst                 8
# 970          970   54    Male    Finance        Analyst                 6
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
finance_department['Promotion_Last_5Years'].value_counts()
# Out:
# Promotion_Last_5Years
# 0    54
# 1    45
# Name: count, dtype: int64

# %% [markdown]
# finance department has currently 99 employees,out of which 45 have been promoted.

# %%
promoted_finance=finance_department['Promotion_Last_5Years']==1
promoted_employees=finance_department.loc[promoted_finance]
promoted_employees
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 17            17   28    Male    Finance     Accountant                 9
# 47            47   39  Female    Finance        Manager                 1
# 50            50   26  Female    Finance  HR Specialist                 5
# 64            64   59    Male    Finance     Accountant                 6
# 93            93   26    Male    Finance        Analyst                 1
# 97            97   49    Male    Finance       Engineer                 5
# 157          157   27  Female    Finance       Engineer                 2
# 168          168   27  Female    Finance       Engineer                 3
# 193          193   41  Female    Finance  HR Specialist                 8
# 205          205   51    Male    Finance  HR Specialist                 3
# 213          213   55  Female    Finance     Accountant                 6
# 218          218   54  Female    Finance     Accountant                 9
# ...

# %% [markdown]
# Employees promoted in the finance department.

# %%
promoted_employees.sort_values(by='Age',ascending=False)
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 64            64   59    Male    Finance     Accountant                 6
# 943          943   58  Female    Finance     Accountant                10
# 591          591   57  Female    Finance  HR Specialist                 4
# 630          630   56  Female    Finance     Accountant                10
# 213          213   55  Female    Finance     Accountant                 6
# 958          958   55    Male    Finance        Manager                 9
# 281          281   55  Female    Finance       Engineer                 3
# 422          422   54  Female    Finance       Engineer                 4
# 218          218   54  Female    Finance     Accountant                 9
# 970          970   54    Male    Finance        Analyst                 6
# 731          731   53    Male    Finance       Engineer                 3
# 736          736   52  Female    Finance     Accountant                 1
# ...

# %% [markdown]
# Two accountants are the oldest employees in age fromnthe finance department whos been promoted.

# %%
promoted_finance=finance_department['Promotion_Last_5Years']==0
unpromoted_employees=finance_department.loc[promoted_finance]
unpromoted_employees
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 27            27   52  Female    Finance  HR Specialist                 6
# 39            39   43    Male    Finance     Accountant                 5
# 51            51   50    Male    Finance  HR Specialist                 7
# 75            75   37  Female    Finance        Analyst                 8
# 94            94   37    Male    Finance        Analyst                 6
# 121          121   28  Female    Finance        Analyst                10
# 125          125   30  Female    Finance       Engineer                 2
# 126          126   58  Female    Finance       Engineer                 2
# 128          128   43    Male    Finance  HR Specialist                10
# 191          191   48    Male    Finance        Manager                10
# 212          212   44  Female    Finance       Engineer                 8
# 267          267   27  Female    Finance       Engineer                 1
# ...

# %%
unpromoted_employees.sort_values(by='Age',ascending=False)
# Out:
#      Employee_ID  Age  Gender Department      Job_Title  Years_at_Company  \
# 967          967   59  Female    Finance        Analyst                 8
# 126          126   58  Female    Finance       Engineer                 2
# 491          491   58    Male    Finance        Analyst                 8
# 903          903   57    Male    Finance  HR Specialist                 4
# 444          444   56    Male    Finance        Manager                 4
# 289          289   56  Female    Finance     Accountant                 2
# 794          794   55    Male    Finance     Accountant                 7
# 27            27   52  Female    Finance  HR Specialist                 6
# 408          408   51  Female    Finance     Accountant                10
# 51            51   50    Male    Finance  HR Specialist                 7
# 823          823   50    Male    Finance        Manager                 2
# 908          908   49  Female    Finance     Accountant                 5
# ...

# %% [markdown]
# An analyst in the finance department who is the oldest in age and has stayed in the company for 8 years has not been promoted,

# %%
df2=df[['Years_at_Company','Satisfaction_Level']]
df2
# Out:
#      Years_at_Company  Satisfaction_Level
# 0                   9            0.586251
# 1                  10            0.261161
# 2                   8            0.304382
# 3                   1            0.480779
# 4                  10            0.636244
# ..                ...                 ...
# 995                 3            0.377435
# 996                 1            0.431152
# 997                 3            0.647102
# 998                 2            0.304813
# 999                 1            0.940510
#
# [1000 rows x 2 columns]

# %%
df2.corr()
# Out:
#                     Years_at_Company  Satisfaction_Level
# Years_at_Company             1.00000            -0.03247
# Satisfaction_Level          -0.03247             1.00000

# %%
df3=df[['Satisfaction_Level','Salary']]
df3
# Out:
#      Satisfaction_Level  Salary
# 0              0.586251   60132
# 1              0.261161   79947
# 2              0.304382   46958
# 3              0.480779   40662
# 4              0.636244   74307
# ..                  ...     ...
# 995            0.377435   71403
# 996            0.431152   30181
# 997            0.647102   64143
# 998            0.304813   74383
# 999            0.940510   73220
#
# [1000 rows x 2 columns]

# %%
df3.corr()
# Out:
#                     Satisfaction_Level    Salary
# Satisfaction_Level            1.000000 -0.027073
# Salary                       -0.027073  1.000000

# %%
df4=df[['Satisfaction_Level','Promotion_Last_5Years','Attrition']]
df4
# Out:
#      Satisfaction_Level  Promotion_Last_5Years  Attrition
# 0              0.586251                      0          0
# 1              0.261161                      1          0
# 2              0.304382                      0          1
# 3              0.480779                      0          0
# 4              0.636244                      1          0
# ..                  ...                    ...        ...
# 995            0.377435                      0          0
# 996            0.431152                      0          1
# 997            0.647102                      0          0
# 998            0.304813                      0          1
# 999            0.940510                      0          1
#
# [1000 rows x 3 columns]

# %%
df4.corr()
# Out:
#                        Satisfaction_Level  Promotion_Last_5Years  Attrition
# Satisfaction_Level               1.000000               0.002927  -0.009601
# Promotion_Last_5Years            0.002927               1.000000   0.017728
# Attrition                       -0.009601               0.017728   1.000000

# %% [markdown]
# There is a positive correlation between satisfaction level and promotion.

# %% [markdown]
# This technically means,promoting the employees makes them more satisfied.

# %% [markdown]
# The company can then consider promoting the employees to make them more satisfied.

# %%
df4['Promotion_Last_5Years'].value_counts()
# Out:
# Promotion_Last_5Years
# 0    514
# 1    486
# Name: count, dtype: int64
